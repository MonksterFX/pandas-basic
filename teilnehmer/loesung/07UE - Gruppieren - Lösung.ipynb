# %% [markdown]
# # Übung 07: Gruppieren
# Im folgenden Abschnitt wollen wir uns unser Olympiadatenset noch genauer anschauen. Hierfür benätigen wir die Datei
# * <font color=orange>bigdata/120-years-of-olympic-history-athletes-and-results/athlete_events.csv</font>
#
# **<font color='red'> Achtung:</font>** bis 1980 wurden die Winterspiele alle zwei Jahre ausgetragen. Dh. in manchen Jahren gibt es sowohl Winter als auch Sommerspiele!</font>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../../src/bigdata/120-years-of-olympic-history-athletes-and-results/athlete_events.csv')
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
# ID        271116 non-null int64
# Name      271116 non-null object
# Sex       271116 non-null object
# Age       261642 non-null float64
# Height    210945 non-null float64
# Weight    208241 non-null float64
# Team      271116 non-null object
# NOC       271116 non-null object
# Games     271116 non-null object
# Year      271116 non-null int64
# Season    271116 non-null object
# City      271116 non-null object
# Sport     271116 non-null object
# Event     271116 non-null object
# Medal     39783 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %% [markdown]
# ## Teilaufgabe 1:
# Zunächst wollen wir erstmal ein paar grundliegende Fragen beantworten zum Datenset beantworten. Dabei hilft uns die Funktion ``.groupby``. Es stellen sich folgende Fragen:
#
# * Wie viele Teilnehmer haben pro Jahr an den Olympischen Sommer Spielen teilgenommen
# * Aus welchen 5 Ländern kammen die meisten Teilnehmer bei den Sommerspielen 2008
# * Wie viele Frauen und Männer insgesamt schon an den Olympischen Spielen teilgenommen haben
# * Wie viele Frauen und Männer in jedem Jahr an den Olympischen Spielen teilgenommen (Unterscheide zusätzlich zwischen Winter und Sommer)
# * Durchschnittsalter der Männer und Frauen
# * Maximalalter der Männer und der Frauen

# %% [markdown]
# **Wie viele Teilnehmer haben pro Jahr an den Olympischen Sommer Spielen teilgenommen**

# %%
df_summer = df[df['Season'] == 'Summer']
df_summer.groupby(['Year']).size().reset_index().tail()
# Out:
#     Year      0
# 24  2000  13821
# 25  2004  13443
# 26  2008  13602
# 27  2012  12920
# 28  2016  13688

# %% [markdown]
# **Aus welchen 5 Ländern kammen die meisten Teilnehmer bei den Sommerspielen 2008**

# %%
df_summer2 = df[(df['Season'] == 'Summer') & (df['Year'] == 2008)]
df_summer2 = df_summer2.groupby(['Year', 'Team']).size().reset_index()
df_summer2 = df_summer2.rename(columns={0:'Count'})
df_summer2.sort_values('Count', ascending=False).head()
# Out:
#      Year           Team  Count
# 278  2008  United States    744
# 53   2008          China    708
# 220  2008         Russia    592
# 12   2008      Australia    559
# 103  2008        Germany    547

# %% [markdown]
# **Wie viele Frauen und Männer insgesamt schon an den Olympischen Spielen teilgenommen haben**

# %%
df.groupby('Sex').size()
# Out:
# Sex
# F     74522
# M    196594
# dtype: int64

# %% [markdown]
# **Wie viele Frauen und Männer in jedem Jahr an den Olympischen Spielen teilgenommen haben**

# %%
df.groupby(['Year', 'Season', 'Sex']).size().reset_index().head()
# Out:
#    Year  Season Sex     0
# 0  1896  Summer   M   380
# 1  1900  Summer   F    33
# 2  1900  Summer   M  1903
# 3  1904  Summer   F    16
# 4  1904  Summer   M  1285

# %% [markdown]
# **Durchschnittsalter der Männer und Frauen**

# %%
df[['Sex', 'Age']].groupby('Sex').mean()
# Out:
#            Age
# Sex
# F    23.732881
# M    26.277562

# %% [markdown]
# **Maximalalter der Männer und der Frauen**

# %%
df[['Sex', 'Age']].groupby('Sex').max()
# Out:
#       Age
# Sex
# F    74.0
# M    97.0

# %% [markdown]
# ## Teilaufgabe 2:
# Wir wollen herausfinden welcher Athlet der/die erfolgreichste war. Erstelle dafür einen neune Dataframe mit dem folgenden Format:
#
# ID|Name|Medal
# ---|---|---
# 4|Edgar Lindenau Aabye|1
# 17|Paavo Johannes Aaltonen|3
# 20|Kjetil Andr Aamodt|4
# 21|Ragnhild Margrethe Aamodt|1
# 40|Roald Edgar Aas|1
#
# Sortiere die Ergebnisse anschließend so, das die Person mit der höchsten Anzahl an goldenen Medalien ganz oben steht.

# %%
df_gold = df[df['Medal'] == 'Gold']
df_gold = df_gold[['ID', 'Medal', 'Name']].groupby(['ID', 'Name']).count()
df_gold = df_gold.reset_index()
df_gold.sort_values(['Medal'], ascending=False).head()
# Out:
#          ID                                Name  Medal
# 7118  94406             Michael Fred Phelps, II     23
# 2410  33557         Raymond Clarence "Ray" Ewry     10
# 5046  67046  Larysa Semenivna Latynina (Diriy-)      9
# 6637  87390                Paavo Johannes Nurmi      9
# 5207  69210      Frederick Carlton "Carl" Lewis      9

# %% [markdown]
# ### Teilaufgabe 3:
# Wir interessieren uns nun für den Medallienspiegel der Atleten. Fasse diesen mit Groupby zusammen und lass dir sortiert nach der Anzahl der Gold, Silber und Bronzemedallien die Athleten ausgeben.
#
# Bereinige außerdem die **NaN** Werte in der Spalte Medal indem du sie durch ein passenden Begriff ersetzt und auch diese Werte in der Auswertung vorkommen.
#
# **Tipp**: Du kannst anstatt ``.reset_index()`` auch ``.unstack()`` benutzen. Schaue dir an welchen Effekt das auf deinen DataFrame hat.

# %%
# Kopieren des Dataframes
df_medals = df.copy()
df_medals['Medal'] = df_medals['Medal'].fillna('Teilnahme')
df_medals = df_medals.groupby(['ID', 'Name' , 'Medal']).size().unstack()
df_medals = df_medals[['Gold', 'Silver', 'Bronze', 'Teilnahme']]
df_medals.sort_values(['Gold', 'Bronze', 'Silver'], ascending=False).head()
# Out:
# Medal                                      Gold  Silver  Bronze  Teilnahme
# ID     Name
# 94406  Michael Fred Phelps, II             23.0     3.0     2.0        2.0
# 33557  Raymond Clarence "Ray" Ewry         10.0     NaN     NaN        NaN
# 67046  Larysa Semenivna Latynina (Diriy-)   9.0     5.0     4.0        1.0
# 113912 Mark Andrew Spitz                    9.0     1.0     1.0        1.0
# 87390  Paavo Johannes Nurmi                 9.0     3.0     NaN        NaN

# %% [markdown]
# ### Teilaufgabe 4:
# Beim Gruppieren bleibt die urspüngliche Sortierung des DataFrames erhalten. Für manche Gruppierungen ist es daher notwendig, das der Dataframe vorher korrekt sortiert wurde.
#
# Finde für jeden Athleten raus, welches sein letztes Jahr war, indem er oder sie angetreten ist. Überprüfe die Lösung indem du zwei bekannte Olympioniken im Internet nachschlägst:
#
# * Michael Fred Phelps, II
# * Raymond Clarence "Ray" Ewry

# %%
df_last = df.sort_values(['ID', 'Year']).groupby('ID').last()
df_last.head()
# Out:
#                         Name Sex   Age  Height  Weight            Team  NOC  \
# ID
# 1                  A Dijiang   M  24.0   180.0    80.0           China  CHN
# 2                   A Lamusi   M  23.0   170.0    60.0           China  CHN
# 3        Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  DEN
# 4       Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 5   Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands  NED
#
#           Games  Year  Season         City          Sport  \
# ID
# 1   1992 Summer  1992  Summer    Barcelona     Basketball
# 2   2012 Summer  2012  Summer       London           Judo
# 3   1920 Summer  1920  Summer    Antwerpen       Football
# 4   1900 Summer  1900  Summer        Paris     Tug-Of-War
# 5   1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                  Event Medal
# ID
# 1          Basketball Men's Basketball   NaN
# 2         Judo Men's Extra-Lightweight   NaN
# 3              Football Men's Football   NaN
# 4          Tug-Of-War Men's Tug-Of-War  Gold
# 5   Speed Skating Women's 1,000 metres   NaN

# %%
df_last[df_last['Name'] == 'Michael Fred Phelps, II']
# Out:
#                           Name Sex   Age  Height  Weight           Team  NOC  \
# ID
# 94406  Michael Fred Phelps, II   M  31.0   193.0    91.0  United States  USA
#
#              Games  Year  Season            City     Sport  \
# ID
# 94406  2016 Summer  2016  Summer  Rio de Janeiro  Swimming
#
#                                             Event Medal
# ID
# 94406  Swimming Men's 4 x 100 metres Medley Relay  Gold

# %%
df_last[df_last['Name'] == 'Raymond Clarence "Ray" Ewry']
# Out:
#                               Name Sex   Age  Height  Weight           Team  \
# ID
# 33557  Raymond Clarence "Ray" Ewry   M  34.0   185.0    79.0  United States
#
#        NOC        Games  Year  Season    City      Sport  \
# ID
# 33557  USA  1908 Summer  1908  Summer  London  Athletics
#
#                                     Event Medal
# ID
# 33557  Athletics Men's Standing Long Jump  Gold

# %% [markdown]
# ## Zusatzaufgabe 1:
# Finde heraus wer die meisten Medallien (unabhänigig ob Gold, Silber oder Bronze) in der jeweiligen Sportkategorie (Spalte Sport) gewonnen hat.

# %%
df_sport = df.copy()
df_sport = df_sport.dropna(subset=['Medal'])
df_sport = df_sport.groupby(['Sport' , 'ID', 'Name']).size().reset_index()
df_sport = df_sport.rename(columns={0:'Count'})
df_sport = df_sport.sort_values('Count', ascending=False)
df_sport.groupby('Sport').first().head()
# Out:
#                       ID                             Name  Count
# Sport
# Aeronautics       107506                Hermann Schreiber      1
# Alpine Skiing         20               Kjetil Andr Aamodt      8
# Alpinism          128001         Arthur William Wakefield      1
# Archery           124694  Gerard Theodor Hubert Van Innis     10
# Art Competitions   28501           Alex Walter Diggelmann      3

# %% [markdown]
# ## Zusatzaufgabe 2:
# Ermittel jeweil den zweitbesten jede Sportkategorie. Außerdem interessieren wir uns für den zweit ältersten in jeder Kategorie.
#
# **Tipp**: In der vielleicht wirst du in der Übersicht der Funktionen für ein GroupBy fündig. <br>
# https://pandas.pydata.org/pandas-docs/stable/reference/groupby.html#computations-descriptive-stats

# %% [markdown]
# **Zweitbeste Person**

# %%
# An dieser stelle können wir den DataFrame aus Zusatzaufgabe 1 wiederverwenden
df_sport.groupby('Sport').nth(2).head()
# Out:
#                       ID                         Name  Count
# Sport
# Alpine Skiing      91797        Anja Sofia Tess Prson      6
# Alpinism          113030    Theodore Howard Somervell      1
# Archery            15721            Julien Louis Brul      5
# Art Competitions   74764          Werner Julius March      2
# Athletics          33557  Raymond Clarence "Ray" Ewry     10

# %% [markdown]
# **Zweitälterste Person**

# %%
# An dieser stelle können wir den DataFrame aus Zusatzaufgabe 1 wiederverwenden
df_oldest = df[['ID', 'Name', 'Age', 'Sport']].sort_values(['ID', 'Age'])
df_oldest = df_oldest.dropna(subset=['Age'])
df_oldest = df_oldest.groupby(['ID', 'Name', 'Sport']).last().reset_index()
df_oldest = df_oldest.sort_values(['Sport', 'Age'])
df_oldest.groupby('Sport').nth(-2)
# Out:
#                                ID  \
# Sport
# Alpine Skiing               83332
# Alpinism                   115888
# Archery                     30932
# Art Competitions            49663
# Athletics                   87632
# Badminton                   76388
# Baseball                    77992
# Basketball                 109581
# Basque Pelota               25866
# Beach Volleyball            48364
# Biathlon                   111941
# Bobsleigh                   32952
# Boxing                     100079
# Canoeing                   100680
# Cricket                      3871
# Croquet                     88258
# Cross Country Skiing        84143
# Curling                    129563
# Cycling                    113913
# Diving                     120570
# Equestrianism               49287
# Fencing                     65675
# Figure Skating              84133
# Football                    78145
# Freestyle Skiing            44143
# Golf                         4330
# Gymnastics                 126029
# Handball                   122690
# Hockey                      49566
# Ice Hockey                 114836
# ...                           ...
# Modern Pentathlon           15720
# Motorboating               120129
# Nordic Combined            110909
# Polo                        92729
# Racquets                    93046
# Rhythmic Gymnastics         21539
# Roque                      115733
# Rowing                       7744
# Rugby                       66682
# Rugby Sevens                74821
# Sailing                     63789
# Shooting                    94490
# Short Track Speed Skating  132262
# Skeleton                    72851
# Ski Jumping                 57803
# Snowboarding                 3824
# Softball                   108231
# Speed Skating              114130
# Swimming                   121258
# Synchronized Swimming       78732
# Table Tennis                85768
# Taekwondo                  105472
# Tennis                      46791
# Trampolining                25057
# Triathlon                   29295
# Tug-Of-War                  15411
# Volleyball                  44944
# Water Polo                  98174
# Weightlifting               74306
# Wrestling                   94843
#
#                                                                   Name   Age
# Sport
# Alpine Skiing                                 Julin Daniel Muoz Zuniga  45.0
# Alpinism                                    Edward Lisle "Bill" Strutt  49.0
# Archery                                          Samuel Harding Duvall  68.0
# Art Competitions                                         Winslow Homer  96.0
# Athletics                               Alexander Harold "Alex" Oakley  50.0
# Badminton                                      Robert Bogumi Mateusiak  40.0
# Baseball                                                Adrian Meagher  41.0
