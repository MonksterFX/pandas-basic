# %%
import random
import pandas as pd
import numpy as np

# %%
# --- new zell ---
df_pokemon = pd.read_csv('../src/pokemon.csv', encoding="utf-8-sig")
df_pokemon
# Out:
#                           Name    Type 1  Type 2  Total   HP  Attack  Defense  \
# 0                    Bulbasaur     Grass  Poison    318   45      49       49
# 1                      Ivysaur     Grass  Poison    405   60      62       63
# 2                     Venusaur     Grass  Poison    525   80      82       83
# 3        VenusaurMega Venusaur     Grass  Poison    625   80     100      123
# 4                   Charmander      Fire     NaN    309   39      52       43
# 5                   Charmeleon      Fire     NaN    405   58      64       58
# 6                    Charizard      Fire  Flying    534   78      84       78
# 7    CharizardMega Charizard X      Fire  Dragon    634   78     130      111
# 8    CharizardMega Charizard Y      Fire  Flying    634  101     104       78
# 9                     Squirtle     Water     NaN    314   44      48       65
# 10                   Wartortle     Water     NaN    405   59      63       80
# ...

# %%
def add_spaces(x):
    c = random.choice([0,1,2])
    return c*" " + x + c*" "

# %%
df_pokemon['Name'] = np.where(df_pokemon['Legendary'], df_pokemon['Name'] + " " + "Legandary", df_pokemon['Name'])

# %%
df_pokemon['Type 2'] = df_pokemon['Type 2'].astype(str)
df_pokemon['Type 1'] = df_pokemon['Type 1'].apply(add_spaces).str.lower()
df_pokemon['Type 2'] = df_pokemon['Type 2'].apply(add_spaces).str.lower()
df_pokemon['Name'] = df_pokemon['Name'].str.lower()
df_pokemon['HP'] = "HP" + df_pokemon['HP'].astype(str)
df_pokemon['Attack'] = "AT" + df_pokemon['Attack'].astype(str)

# %%
# suchen in texten
df_pokemon[df_pokemon['Name'].str.contains('pika')]
# Out:
#        Name    Type 1   Type 2  Total    HP Attack  Defense  Sp. Atk  Sp. Def  \
# 30  pikachu  electric    nan      320  HP35   AT55       40       50       50
#
#     Speed  Generation  Legendary
# 30     90           1      False

# %%
df_pokemon.sort_values('Name').head()
# Out:
#                         Name       Type 1   Type 2  Total    HP Attack  \
# 510                abomasnow        grass      ice    494  HP90   AT92
# 511  abomasnowmega abomasnow        grass      ice    594  HP90  AT132
# 68                      abra    psychic        nan    310  HP25   AT20
# 392                    absol       dark       nan     465  HP65  AT130
# 393          absolmega absol       dark      nan      565  HP65  AT150
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 510       75       92       85     60           4      False
# 511      105      132      105     30           4      False
# 68        15      105       55     90           1      False
# 392       60       75       60     75           3      False
# 393       60      115       60    115           3      False

# %%
df_pokemon['Stats'] = df_pokemon['HP'].str.cat(df_pokemon['Attack'], sep="-").copy()

# %%
df_pokemon = df_pokemon[['Name', 'Type 1', 'Type 2', 'Stats']]
df_pokemon.to_csv('../src/pokemon_defekt.csv', encoding="utf-8", index=False)
