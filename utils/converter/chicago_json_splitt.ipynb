# %%
import pandas as pd
import json

# %%
path = r"\\home.rrze.uni-erlangen.de\douk11ibag\Documents\Python\git\pandas-basic\utils\converter\column_remapping.json"

# %%
with open(path, "r") as f:
    j = json.load(f)

# %%
j.keys()
# Out:
# dict_keys(['taxi_id', 'company', 'pickup_census_tract', 'dropoff_census_tract', 'pickup_latitude', 'pickup_longitude', 'dropoff_latitude', 'dropoff_longitude'])

# %%
export_path = r"\\home.rrze.uni-erlangen.de\douk11ibag\Documents\Python\git\pandas-basic\teilnehmer\abschlussuebung\{}.json"
obj = 'dropoff_longitude'


with open(export_path.format(obj), 'w') as f:
    json.dump(j.get(obj), f)

# %%
j.get(obj)
# Out:
# {'0': '-87.811605775',
#  '1': '-87.670621043',
#  '2': '-87.656411531',
#  '3': '-87.672538401',
#  '4': '-87.61626757',
#  '5': '-87.601759821',
#  '6': '-87.903039661',
#  '7': '-87.781286562',
#  '8': '-87.708416729',
#  '9': '-87.735092701',
#  '10': '-87.731711853',
#  '11': '-87.651692953',
#  '12': '-87.680928225',
#  '13': '-87.69947972',
#  '14': '-87.641070746',
#  '15': '-87.673574032',
#  '16': '-87.599476602',
#  '17': '-87.638477183',
#  '18': '-87.731002484',
#  '19': '-87.738569226',
#  '20': '-87.619249758',
#  '21': '-87.661642904',
#  '22': '-87.6531587',
#  '23': '-87.648626816',
#  '24': '-87.72345239',
#  '25': '-87.73082849',
#  '26': '-87.698674017',
#  '27': '-87.621436144',
#  '28': '-87.582365702',
#  '29': '-87.738937205',
#  '30': '-87.684685949',
#  '31': '-87.579948248',
#  '32': '-87.654007029',
#  '33': '-87.759857019',
#  '34': '-87.717334502',
#  '35': '-87.781964023',
#  '36': '-87.780270163',
#  '37': '-87.645089635',
#  '38': '-87.722404275',
# ...

# %%
pd.read_json(<path to source>, typ='series', dtype='float')
# Out:
# 0     -87.811606
# 1     -87.670621
# 2     -87.656412
# 3     -87.672538
# 4     -87.616268
# 5     -87.601760
# 6     -87.903040
# 7     -87.781287
# 8     -87.708417
# 9     -87.735093
# 10    -87.731712
# 11    -87.651693
# 12    -87.680928
# 13    -87.699480
# 14    -87.641071
# 15    -87.673574
# 16    -87.599477
# 17    -87.638477
# 18    -87.731002
# 19    -87.738569
# 20    -87.619250
# 21    -87.661643
# 22    -87.653159
# 23    -87.648627
# 24    -87.723452
# 25    -87.730828
# 26    -87.698674
# 27    -87.621436
# 28    -87.582366
# 29    -87.738937
#          ...
# 756   -87.762286
# 757   -87.750934
# 758   -87.660389
# 759   -87.689951
# 760   -87.666611
# 761   -87.643023
# 762   -87.742788
# 763   -87.702007
# 764   -87.563693
# 765   -87.694964
# 766   -87.621499
# 767   -87.689126
# 768   -87.594015
# 769   -87.752012
# 770   -87.726363
# 771   -87.721559
# 772   -87.757597
# 773   -87.575637
# 774   -87.713435
# 775   -87.635891
# 776   -87.651409
# ...
