# %% [markdown]
# # Usefull Links
# https://nbconvert.readthedocs.io/en/latest/removing_cells.html

# %% [markdown]
# # Main

# %%
import os
import pdfkit
from nbconvert.exporters import HTMLExporter

# config
path_wkthmltopdf = r"C:\Program Files\wkhtmltopdf\bin\wkhtmltopdf.exe"
config = pdfkit.configuration(wkhtmltopdf=path_wkthmltopdf)
start_path = '../../referent'

options = {
    'page-size': 'A4',
    'margin-top': "2cm",
    'margin-bottom': "2cm",
    'margin-left': "2cm",
    'margin-right': "2cm",
}

# %%
for entry in os.scandir(start_path):
    if entry.is_file() and entry.name.endswith(".ipynb"):  
        (body, resources) = HTMLExporter().from_filename(os.path.join(start_path,entry.name))
        pdfkit.from_string(body, os.path.join(start_path, entry.name + '.pdf'), configuration=config, options=options)
# Out:
# Loading pages (1/6)
# ...
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# Loading pages (1/6)
# ...
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# Loading pages (1/6)
# ...
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# Loading pages (1/6)
# ...
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# Loading pages (1/6)
# ...
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# Loading pages (1/6)
# ...
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# Loading pages (1/6)
# ...
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# Loading pages (1/6)
# ...
# Counting pages (2/6)
# ...
